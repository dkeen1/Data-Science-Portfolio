# %% [markdown]
# ### Decision Tree Practice, working through Udemy Course Project

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
loans = pd.read_csv('C:/Users/danie/loan_data.csv')

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %% [markdown]
# ### EDA - Pandas and Seaborn Data Visualizations

# %%
fig, ax = plt.subplots()

#creating fico distribution histograms
loans1 = loans.loc[loans['credit.policy']==1]
loans1.hist(column = 'fico', ax = ax, bins= 30, alpha=.5)

loans2 = loans.loc[loans['credit.policy']==0]
loans2.hist(column = 'fico', ax=ax, bins=30, alpha=.5)

plt.legend(['Credit Policy 1', 'Credit Policy 0'])

# %%
#similar, doing this by the not fully paid column
fig1, ax1 = plt.subplots()

loans_paid = loans.loc[loans['not.fully.paid'] == 0]
loans_paid.hist(column = 'fico', ax = ax1, bins = 30, alpha=.5)

loans_not_paid = loans.loc[loans['not.fully.paid'] == 1]
loans_not_paid.hist(column='fico', ax = ax1, bins = 30, alpha=.5)

plt.legend(['Fully Paid', 'Not Fully Paid'])

# %%
#countplot with seaborn showing counts of loans by purpose, with hue being not fully paid`
sns.countplot(data = loans, x='purpose', hue='not.fully.paid')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'debt_consolidation'),
#   Text(1, 0, 'credit_card'),
#   Text(2, 0, 'all_other'),
#   Text(3, 0, 'home_improvement'),
#   Text(4, 0, 'small_business'),
#   Text(5, 0, 'major_purchase'),
#   Text(6, 0, 'educational')])

# %%
sns.jointplot(x='fico', y='int.rate', data = loans, color='purple')

# %%
plt.figure(figsize=(11,7))
sns.lmplot(y='int.rate', x='fico', data=loans, hue='credit.policy', col='not.fully.paid', palette='Set1')

# %%
loans[['fico','int.rate']].corr(method='pearson')
# Out:
#               fico  int.rate
# fico      1.000000 -0.714821
# int.rate -0.714821  1.000000

# %% [markdown]
# ### Getting the Data Ready for Modeling

# %%
cat_feats = ['purpose']

# %%
final_data = pd.get_dummies(loans, columns=cat_feats, drop_first=True, dtype = 'int')
#kept purpose out of the final dataframe, because we wanted the dummy variables out by themselves

# %%
final_data.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  purpose_credit_card  purpose_debt_consolidation  \
# ...

# %% [markdown]
# ### Making the Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import classification_report

# %%
tree = DecisionTreeClassifier(random_state = 42)
y = final_data[['not.fully.paid']]
x = final_data.drop(columns='not.fully.paid')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .30, random_state = 101)

# %%
dtree = tree.fit(x_train, y_train)

# %%
y_pred = dtree.predict(x_test)

# %%
print(y_pred)
# Out:
# [0 1 0 ... 0 0 0]

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84      2431
#            1       0.19      0.23      0.21       443
#
#     accuracy                           0.73      2874
#    macro avg       0.52      0.52      0.52      2874
# weighted avg       0.75      0.73      0.74      2874

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[2015  393]
#  [ 368   98]]

# %% [markdown]
# ### Making a Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_leaf_nodes=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=600, n_jobs=1,
            oob_score=False, random_state=42, verbose=0,
            warm_start=False)

# %%
forest_fit = forest.fit(x_train, y_train)
# Out:
# C:\Users\danie\anaconda3\envs\home_env\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
y_pred_forest = forest_fit.predict(x_test)

# %%
print(classification_report(y_test, y_pred_forest, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2408
#            1       0.48      0.02      0.04       466
#
#     accuracy                           0.84      2874
#    macro avg       0.66      0.51      0.48      2874
# weighted avg       0.78      0.84      0.77      2874

# %%
print(confusion_matrix(y_test, y_pred_forest))
# Out:
# [[2397   11]
#  [ 456   10]]
